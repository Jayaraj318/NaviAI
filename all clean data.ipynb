# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer

data=pd.read_csv(r"C:\Users\Jayaraj.V\OneDrive\Desktop\SIH\flight_data.csv")
numeric_cols = data.select_dtypes(include=['number']).columns
categorical_cols = data.select_dtypes(include=['object']).columns
numeric_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
data[numeric_cols] = numeric_imputer.fit_transform(data[numeric_cols])
categorical_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
data[categorical_cols] = categorical_imputer.fit_transform(data[categorical_cols])
data.to_csv(r'C:\Users\Jayaraj.V\OneDrive\Desktop\SIH\new\new cleaned flight.csv', index=False)

# %%
data=pd.read_csv(r"C:\Users\Jayaraj.V\OneDrive\Desktop\SIH\new\new cleaned flight.csv")

# %%
data.isnull()
# Out:
#        icao24  callsign  origin_country  time_position  last_contact  \
# 0       False     False           False          False         False
# 1       False     False           False          False         False
# 2       False     False           False          False         False
# 3       False     False           False          False         False
# 4       False     False           False          False         False
# ...       ...       ...             ...            ...           ...
# 10851   False     False           False          False         False
# 10852   False     False           False          False         False
# 10853   False     False           False          False         False
# 10854   False     False           False          False         False
# 10855   False     False           False          False         False
#
#        longitude  latitude  baro_altitude  on_ground  velocity  heading  \
# ...

# %%
data.dropna()
# Out:
#        icao24  callsign origin_country  time_position  last_contact  \
# 0      4b1816  SWR438A     Switzerland   1.723570e+09  1.723570e+09
# 1      a4754b  N387A     United States   1.723570e+09  1.723570e+09
# 2      80162d  AXB747            India   1.723570e+09  1.723570e+09
# 3      e8027d  LPE2086           Chile   1.723570e+09  1.723570e+09
# 4      a57b26  N452SM    United States   1.723570e+09  1.723570e+09
# ...       ...       ...            ...            ...           ...
# 10851  a05dba  UAL1782   United States   1.723570e+09  1.723570e+09
# 10852  458666  CAT762          Denmark   1.723570e+09  1.723570e+09
# 10853  c067ae  ACA410           Canada   1.723570e+09  1.723570e+09
# 10854  c00734  WJA1596          Canada   1.723570e+09  1.723570e+09
# 10855  a60bbd  WUP489    United States   1.723570e+09  1.723570e+09
#
#        longitude  latitude  baro_altitude  on_ground  velocity  heading  \
# 0         4.3309   50.2606   11887.200000      False    226.33   120.00
# ...

# %%
boolean_cols = data.select_dtypes(include=['bool']).columns
data[boolean_cols] = data[boolean_cols].astype(int)

# %%
data
# Out:
#        icao24  callsign origin_country  time_position  last_contact  \
# 0      4b1816  SWR438A     Switzerland   1.723570e+09  1.723570e+09
# 1      a4754b  N387A     United States   1.723570e+09  1.723570e+09
# 2      80162d  AXB747            India   1.723570e+09  1.723570e+09
# 3      e8027d  LPE2086           Chile   1.723570e+09  1.723570e+09
# 4      a57b26  N452SM    United States   1.723570e+09  1.723570e+09
# ...       ...       ...            ...            ...           ...
# 10851  a05dba  UAL1782   United States   1.723570e+09  1.723570e+09
# 10852  458666  CAT762          Denmark   1.723570e+09  1.723570e+09
# 10853  c067ae  ACA410           Canada   1.723570e+09  1.723570e+09
# 10854  c00734  WJA1596          Canada   1.723570e+09  1.723570e+09
# 10855  a60bbd  WUP489    United States   1.723570e+09  1.723570e+09
#
#        longitude  latitude  baro_altitude  on_ground  velocity  heading  \
# 0         4.3309   50.2606   11887.200000          0    226.33   120.00
# ...

# %%
data.rename(columns={
    'icao24': 'Aircraft_ICAO24',
    'callsign': 'Callsign',
    'origin_country': 'Origin_Country',
    'time_position': 'Time_Position',
    'last_contact': 'Last_Contact',
    'longitude': 'Longitude',
    'latitude': 'Latitude',
    'baro_altitude': 'Barometric_Altitude',
    'on_ground': 'On_Ground',
    'velocity': 'Velocity',
    'heading': 'Heading',
    'vertical_rate': 'Vertical_Rate',
    'geo_altitude': 'Geometric_Altitude',
    'squawk': 'Squawk_Code',
    'spi': 'SPI_Indicator',
    'position_source': 'Position_Source'
}, inplace=True)

# %%
df = data.round(2)

# %%
df
# Out:
#       Aircraft_ICAO24  Callsign Origin_Country  Time_Position  Last_Contact  \
# 0              4b1816  SWR438A     Switzerland   1.723570e+09  1.723570e+09
# 1              a4754b  N387A     United States   1.723570e+09  1.723570e+09
# 2              80162d  AXB747            India   1.723570e+09  1.723570e+09
# 3              e8027d  LPE2086           Chile   1.723570e+09  1.723570e+09
# 4              a57b26  N452SM    United States   1.723570e+09  1.723570e+09
# ...               ...       ...            ...            ...           ...
# 10851          a05dba  UAL1782   United States   1.723570e+09  1.723570e+09
# 10852          458666  CAT762          Denmark   1.723570e+09  1.723570e+09
# 10853          c067ae  ACA410           Canada   1.723570e+09  1.723570e+09
# 10854          c00734  WJA1596          Canada   1.723570e+09  1.723570e+09
# 10855          a60bbd  WUP489    United States   1.723570e+09  1.723570e+09
#
# ...

# %%
df.drop_duplicates()
# Out:
#       Aircraft_ICAO24  Callsign Origin_Country  Time_Position  Last_Contact  \
# 0              4b1816  SWR438A     Switzerland   1.723570e+09  1.723570e+09
# 1              a4754b  N387A     United States   1.723570e+09  1.723570e+09
# 2              80162d  AXB747            India   1.723570e+09  1.723570e+09
# 3              e8027d  LPE2086           Chile   1.723570e+09  1.723570e+09
# 4              a57b26  N452SM    United States   1.723570e+09  1.723570e+09
# ...               ...       ...            ...            ...           ...
# 10851          a05dba  UAL1782   United States   1.723570e+09  1.723570e+09
# 10852          458666  CAT762          Denmark   1.723570e+09  1.723570e+09
# 10853          c067ae  ACA410           Canada   1.723570e+09  1.723570e+09
# 10854          c00734  WJA1596          Canada   1.723570e+09  1.723570e+09
# 10855          a60bbd  WUP489    United States   1.723570e+09  1.723570e+09
#
# ...

# %%
df.to_csv(r'C:\Users\Jayaraj.V\OneDrive\Desktop\SIH\new\CLEANED DATA.csv', index=False)
