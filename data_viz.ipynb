# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Exploratory data analysis</p>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Explore the Data</p>

# %%
df = pd.read_csv('shipment_data.csv')
df
# Out:
#       Aircraft_ICAO24 Callsign Origin_Country  Time_Position  Longitude  \
# 0              4b1816  SWR438A    Switzerland     1723570180       4.33
# 1              a4754b    N387A  United States     1723569940    -110.10
# 2              80162d   AXB747          India     1723570180      56.24
# 3              e8027d  LPE2086          Chile     1723570180     -77.29
# 4              a57b26   N452SM  United States     1723570180    -104.98
# ...               ...      ...            ...            ...        ...
# 10851          a05dba  UAL1782  United States     1723570180     -92.64
# 10852          458666   CAT762        Denmark     1723570180       4.58
# 10853          c067ae   ACA410         Canada     1723569730     -73.75
# 10854          c00734  WJA1596         Canada     1723570180    -114.42
# 10855          a60bbd   WUP489  United States     1723570180     -78.42
#
#        Latitude  Barometric_Altitude  Velocity  Heading  Vertical_Rate  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10856 entries, 0 to 10855
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Aircraft_ICAO24      10856 non-null  object
#  1   Callsign             10856 non-null  object
#  2   Origin_Country       10856 non-null  object
#  3   Time_Position        10856 non-null  int64
#  4   Longitude            10856 non-null  float64
#  5   Latitude             10856 non-null  float64
#  6   Barometric_Altitude  10856 non-null  float64
#  7   Velocity             10856 non-null  float64
#  8   Heading              10856 non-null  float64
#  9   Vertical_Rate        10856 non-null  float64
#  10  Geometric_Altitude   10856 non-null  float64
#  11  Squawk_Code          10856 non-null  float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 1017.9+ KB

# %%
sns.set_style('white')
sns.set(rc={
    "axes.facecolor" : "#27a102",
    "figure.facecolor" : "#000000"

})

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Distribution of Barometric Altitude</p>

# %%
sns.histplot(data=df, x='Barometric_Altitude', kde=True, bins=30, alpha=1, color='#ffbf00', edgecolor = 'white')
plt.xlim(0,16000)
plt.xlabel('Barometric Altitude').set_color('white')
plt.ylabel('Frequency').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Gepmetric Altitude</p>

# %%
sns.histplot(data=df, x='Geometric_Altitude', kde=True, bins=30, alpha=1, color='#ffbf00' )
plt.xlim(0,16000)
plt.xlabel('Geometric Altitude').set_color('white')
plt.ylabel('Frequency').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Distribution of Heading</p>

# %%
sns.histplot(data=df, x='Heading', kde = True, bins=30, alpha=1, color='#ffbf00', edgecolor = 'white', line_kws={'color': 'black'})
plt.xlabel('Heading').set_color('white')
plt.ylabel('Frequency').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Velocity</p>

# %%
sns.histplot(data=df, x='Velocity', kde=True, bins=30,alpha=1, color='#ffbf00', edgecolor = 'white' )
plt.xlim(0, 350)
plt.xlabel('Velocity').set_color('white')
plt.ylabel('Frequency').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Vertical Rate</p>

# %%
sns.histplot(data=df, x='Vertical_Rate', kde=True, bins=30,alpha=1, color='#ffbf00', edgecolor = 'white')
plt.xlabel('Vertical_Rate').set_color('white')
plt.ylabel('Frequency').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">corrlation Analysis</p>

# %%
df2 = df.drop(columns=['Aircraft_ICAO24','Callsign', 'Origin_Country'])

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(data=df2.corr(), annot=True)
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Barometric Altitude vs Geometric Altitude</p>

# %%
plt.scatter(df['Barometric_Altitude'], df['Geometric_Altitude'], c='#ffbf00')
plt.xlabel('Barometric_Altitude').set_color('white')
plt.ylabel('Geometric_Altitude').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Velocity vs Geometric Altitude</p>

# %%
plt.scatter(df['Velocity'], df['Geometric_Altitude'], c='#ffbf00')
plt.xlabel('Velocity').set_color('white')
plt.ylabel('Geometric_Altitude').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#27a102;margin:0;color:#111111;font-family:courier;font-size:100%;text-align:center;border-radius: 50px 50px;overflow:hidden;font-weight:bold">Velocty vs Barometric Altitude</p>

# %%
plt.scatter(df['Velocity'], df['Barometric_Altitude'],  c='#ffbf00')
plt.xlabel('Velocity').set_color('white')
plt.ylabel('Barometric_Altitude').set_color('white')
plt.xticks(color='white')
plt.yticks(color='white')
plt.show()
